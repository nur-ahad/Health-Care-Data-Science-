# %%
#Import Libraries 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Load the dataset 
df  = pd.read_csv("heart.csv")

# %%
#EDA 
#To see the headings 
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
#Sumary/Description of the dataset 
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#To view info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Histogram of Age
df.age.hist()
plt.show()

# %%
#Countplat of sex
sns.countplot(df.sex)
plt.show()
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Countplat of cp 
sns.countplot(df.cp)
plt.show()
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#trestbps 
df.age.hist()
plt.show()

# %%
#  chol   

sns.countplot(df.cp)
plt.show()
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#cp 
sns.countplot(df.cp)
plt.show()
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Missing valuw analysis
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#Correlation analysis 
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#Train-Test Split of dataset 
from sklearn.model_selection import train_test_split
predictors =df.drop("target", axis=1)
target = df["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
#Shape of X-Train Dataset 
X_train.shape
# Out:
# (242, 13)

# %%
#Shape of X-Test Dataset 
X_test.shape
# Out:
# (61, 13)

# %%
#Shape of Y-train Dataset
Y_train.shape
# Out:
# (242,)

# %%
#Shape of the Y-test Dataset
Y_test.shape
# Out:
# (61,)

# %%
#Logistic Regression Algorithm 
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,Y_train)
Y_pred_lr = lr.predict(X_test)
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
#Accuracy score of Logistic Regression
from sklearn.metrics import accuracy_score
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)
print("The accuracy score of Logistic Regression is:   "+str(score_lr)+" %")
# Out:
# The accuracy score of Logistic Regression is:   85.25 %

# %%
#Support Vector Machine (SVM) Algorithm 
from sklearn import svm
sv = svm.SVC(kernel='linear')
sv.fit(X_train,Y_train)
Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
#Accuracy score of Support Vector Machine
from sklearn.metrics import accuracy_score
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)
print("The accuracy score of Support Vector Machine is:   "+str(score_svm)+" %")
# Out:
# The accuracy score of Support Vector Machine is:   81.97 %

# %%
pip install xgboost
# Out:
# ...
#      ---------------------------------------- 89.1/89.1 MB 9.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#XGBoost 
import xgboost as xgb
xgb_model =xgb.XGBClassifier(objective ="binary:logistic", random_state =42)
xgb_model.fit(X_train,Y_train)
Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
#Accuracy score of XGBoost
from sklearn.metrics import accuracy_score
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)
print("The accuracy score of XGB is:   "+str(score_xgb)+" %")
# Out:
# The accuracy score of XGB is:   78.69 %

# %%
from tensorflow import keras

# %%
#Neural Network Algorithm 
from keras.models import Sequential 
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation="relu", input_dim =13))
model.add(Dense(1,activation ='sigmoid'))

model.compile (loss ='binary_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.fit(X_train,Y_train,epochs =300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 0s 987us/step - loss: 0.3701 - accuracy: 0.8471
# Epoch 2/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8347
# Epoch 3/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8223
# Epoch 4/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8512
# Epoch 5/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.8140
# Epoch 6/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8595
# Epoch 7/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8388
# Epoch 8/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8471
# Epoch 9/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8471
# Epoch 10/300
# ...

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 1ms/step

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]
Y_pred_nn = rounded

# %%
#Accuracy score of Support Vector Machine
from sklearn.metrics import accuracy_score
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)
print("The accuracy score of Neural Network is:   "+str(score_nn)+" %")
# Out:
# The accuracy score of Neural Network is:   85.25 %

# %%
#Output of Scores 
scores = [score_lr,score_svm,score_xgb,score_nn]
algorithms = ["Logistic Regression","Support Vector Machine","XGBoost","Neural Network"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %" )
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %
# The accuracy score achieved using Support Vector Machine is: 81.97 %
# The accuracy score achieved using XGBoost is: 78.69 %
# The accuracy score achieved using Neural Network is: 85.25 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms, scores)
# Out:
# C:\Users\nural\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Algorithms', ylabel='Accuracy score'>
